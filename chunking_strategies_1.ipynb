# %%
# imports
import os
from langchain_text_splitters import MarkdownHeaderTextSplitter, CharacterTextSplitter, RecursiveCharacterTextSplitter

# %%
# Step 1: Function to read input documents
def read_document(file_path):
    ''' 
    Reads a document based on its extension.
    Returns its content and a boolean indicating if it is a markdown file.
    '''
    _, file_extension = os.path.splitext(file_path)
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read(), file_extension == '.md'

# %%
# Step 2: Combined chunking strategy function
def split_strategy(text, chunk_size, chunk_overlap, is_markdown, strategy):
    '''
    Splits the text using the specified chunking strategy.
    Return a list of text chunks.
    '''
    if 'markdown' in strategy and is_markdown:
        headers_to_split_on = [
            ("#", "Header 1"),
            ("##", "Header 2"),
            ('###', 'Header 3')]
        md_splitter = MarkdownHeaderTextSplitter(
            headers_to_split_on=headers_to_split_on, strip_headers=False)
        text = md_splitter.split_text(text)
        if strategy == 'markdown':
            print(f"hello hello")
            return [doc.page_content for doc in text]
        strategy = strategy.split('-')[1]  # Get 'fixed' or 'recursive'

    if strategy == 'fixed':
        print(f"came here")
        splitter = CharacterTextSplitter(
            separator=SEPARATOR, chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    elif strategy == 'recursive':
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    else:
        raise ValueError(f"Unsupported chunking strategy: {strategy}")

    if is_markdown:
        documents = splitter.split_documents(text)
        return [doc.page_content for doc in documents]
    else:
        return splitter.split_text(text)

# %%
# Global parameters
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 100
SEPARATOR = "\n\n" # other options are: "\n" or "",""

def process_document(file_path, strategy):
    '''
    Processes the document and splits it into chunks using the specified strategy.
    Returns a list of text chunks.
    '''
    document_content, is_md = read_document(file_path)
    
    chunks = split_strategy(
        document_content, 
        chunk_size=CHUNK_SIZE, 
        chunk_overlap=CHUNK_OVERLAP, 
        is_markdown=is_md, 
        strategy=strategy)
    return chunks

# %%
file_path = 'Employee guide.pdf.md'
strategies = ['fixed', 'recursive', 'markdown', 'markdown-fixed', 'markdown-recursive']
chunks = process_document(file_path, strategy='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 file_path = 'Employee guide.pdf.md'
#       2 strategies = ['fixed', 'recursive', 'markdown']
# ----> 3 chunks = process_document(file_path, strategy='')
#
# Cell In[38], line 14, in process_document(file_path, strategy)
#       7 '''
#       8 Processes the document and splits it into chunks using the specified strategy.
#       9 Returns a list of text chunks.
#      10 '''
#      11 document_content, is_md = read_document(file_path)
# ---> 14 chunks = split_strategy(
#      15     document_content,
#      16     chunk_size=CHUNK_SIZE,
#      17     chunk_overlap=CHUNK_OVERLAP,
#      18     is_markdown=is_md,
#      19     strategy=strategy)
#      20 return chunks
#
# Cell In[41], line 28, in split_strategy(text, chunk_size, chunk_overlap, is_markdown, strategy)
#      25     splitter = RecursiveCharacterTextSplitter(
#      26         chunk_size=chunk_size, chunk_overlap=chunk_overlap)
#      27 else:
# ---> 28     raise ValueError(f"Unsupported chunking strategy: {strategy}")
#      30 if is_markdown:
#      31     documents = splitter.split_documents(text)
#
# ValueError: Unsupported chunking strategy:

# %%
(chunks)
# Out:
# ['Note: ClearPeaks at its own discretion, may change, delete, suspend or discontinue parts or the policy in its entirety,\nat any time without prior notice.',
#  '# WORKING AT CLEARPEAKS  \n**June 23**',
#  '## CONTENT TABLE  \n1. Introduction\n1.1Welcome\n1.2 Company Values\n2. Employee definition and status\n2.1 Probationary Period for New Employees\n3. Employee Policies\n3.1 Equal Employee Opportunity\n3.2 Employee Background Check\n3.3 New Employee Orientation\n3.4 Personnel Records and Administration\n3.5 Change of Personal Data\n3.6 Safety\n3.7 Health & Absence\n3.8 Employee Requiring Medical Attention\n3.9 Visitors in the Workplace\n4. Standards of Conduct\n4.1 General Guidelines\n4.2 Attendance and Punctuality\n4.3 Work Schedule\n4.4 Meal and Break Periods\n4.5 Hybrid Working Model\n4.6 Absence and Lateness\n4.7 Unscheduled Absence\n4.8 Voice mail, out-of-office message, e-mail signatures, communication, etc.\n4.9 Harassment Policy\n4.10 Violent Behaviour in the Workplace\n4.11 Confidential Information and Non-disclosure\n4.12 Ethical Standards\n4.13 Personal Image\n4.14 Dress Code\n4.15 Use of Equipment\n4.16 Use of the Internet\n4.17 Use of Computer Software\n4.18 Smoking Policy\n4.19 Alcohol and Substance Abuse\n4.20 Bribery Policy\n4.21 Solicitations and Distributions\n4.22 Complaint Procedure\n4.23 Corrective Procedure\n4.24 Crisis Suspension\n4.25 Transfer Policy\n4.26 Outside Employment & Non-solicitation\n4.27 Employment Termination or Resignation\n4.28 Exit Interview\n5. Compensation Policies\n5.1 Compensation & Benefits\n5.2 Timekeeping Procedures\n5.3 Payroll and Pay Days\n5.4 Performance and Salary Reviews\n5.5 Opportunities for Advancement – Progression and Promotion\n5.6 Training and Professional Development\n5.7 Training and Professional Development\n5.8 Holiday Policy\n5.9 Non-business working daytime policy\n5.10 Special days off\n5.11 Personal Leaves or Absence\n6. Travel Expenses\n7. Company Supplies & Purchases\n8. Employee Communications\n8.1 Open communications\n8.2 Staff Meetings\n8.3 Suggestions\n8.4 Closing Statement',
#  '## 1. Introduction  \n### Welcome\nWelcome to ClearPeaks! We are delighted to have you on board as a new member of our team.  \nThis document is intended to help you familiarize with information about work practices, key\npolicies & procedures and benefits relating to working at ClearPeaks.  \nPlease make sure to read through this guide and be sure to speak to your HR Team if you have any\ndoubts or questions.',
#  "### Company Values  \nOur core values are apparent in everything we do and its these values that differentiate us from\nour competitors.  \nWe pride ourselves on being a modern and human company – after all, quality people, a healthy\nworking atmosphere and close relationships are essential to successful solution delivery.  \nOther than our complete commitment to quality, customer satisfaction and project success, the\nteam at ClearPeaks shares core values which help to set us apart, as follows:  \n#### Teamwork & Collaboration  \nTeamwork and collaboration are paramount to our success, whether engaged in customer\nprojects or working internally in administrative teams.  \n#### Pragmatism  \nWe work with the basic principle of management by common sense, doing the right thing at the\nright moment, based on a well debated thought process and plan.  \n#### Quality  \nWe recognise that it is not the 80% job done that makes the impact at our customers – in fact, it\nis the final 20%. The focus on every detail, the polish that separates us from the pack. We expect\neveryone at ClearPeaks to be focused on a 100% quality service to maintain our brand and\nreputation, whether at customer or internally.  \n#### Integrity  \nIt is vital that we are honest and transparent with our customers and colleagues, even if\nsometimes it disappoints or impacts negatively on expectations. This means that all planning,\nproposals, or suggestions need to be well considered and all options explored before\ncommunicating any negative message to our customers. But in the end, transparency is best.  \n#### Mutual Respect  \nFor colleagues’ opinions, race, colour, job level, personal choices etc – respect develops trust,\nhealthy working relationships and contributes to a happy culture.  \n#### Commitment  \nWorking hard, diligently and focusing on getting the job done efficiently to make your project a\nsuccess - more will come as a result.  \n#### Human & Caring  \nLet's keep our human spirit, as everyone deserves this, so let's make sure we do not discriminate\nwith who gets our attention – everyone should be cared for.  \n#### Innovation  \nWe rely on all our employees to look for innovation take-aways in all we do – whether in\ncustomer projects, internal objectives, or office admin areas. Looking for the best innovative and\ncreative solution is what our customers look for in a niche service, so let’s deliver.",
#  '## 2. Employee definition and status  \nAn “employee” of ClearPeaks is a person who is employed with an official working contract with\nClearPeaks.',
#  '### Probationary Period for New Employees  \nClearPeaks monitors and evaluates every new employee’s performance to determine whether\nfurther employment in a specific position or with ClearPeaks is appropriate.  \n#### Region Probation period (Months)\nSpain: 6\nCroatia: 6\nUAE: 6',
#  '## 3. Employee Policies  \n### Equal Employee Opportunity  \nClearPeaks is an equal employment opportunity employer. Employment decisions are based on\nmerit and business needs, and not on race, colour, citizenship status, national origin, ancestry,\ngender, sexual orientation, age, weight, religion, creed, physical or mental disability, marital status,\nveteran status, political affiliation, or any other factor protected by law.',
#  '### Employee Background Check  \nPrior to making an offer of employment, ClearPeaks may conduct a job-related background check.\nA comprehensive background check may consist of prior employment verification, professional\nreference checks, education confirmation.  \nA subcontractor will be requested to provide 2 business references including their latest,\ncompleted assignment.',
#  '### New Employee Orientation  \nThe formal welcoming process, or “employee orientation,” is conducted by a designated team\nmember, and includes an overview of the company core business, operations, team etc. This may\nwell involve a stand-up personal introduction of the newly starting employee.',
#  '### Personnel Records and Administration  \nThe task of handling personnel records and related administration functions at ClearPeaks is\nmanaged by the company administrator. Personnel files should be kept confidential at all times\nand include the following documents:  \n- Photocopy of the DNI/ Passport\n- Social Security documentation\n- Work Permit (non-EU only)\n- Remuneration details: bank account\n- Personal information, emergency medical information  \nAny medical records or criminal records must be made known to a member of ClearPeaks\nmanagement team at the earliest possible opportunity. All medical or criminal records, if any, will\nbe kept in a separate confidential file.',
#  '### Change of Personal Data  \nAny change in an employee’s name, address, telephone number, marital status, dependents\n(children, etc.), or a change in the number of tax withholding exemptions, needs to be reported\nin writing without delay to the company administrator.',
#  '### Safety  \nThe safety and health of employees is a priority. ClearPeaks makes every effort to comply with all\nworkplace safety requirements and in accordance with local regulations.  \nEach employee is expected to obey safety rules and exercise caution and common sense in all\nwork activities.',
#  '### Health & Absence  \nIn case of sickness or other unplanned absence, a member of the management team should be\ninformed immediately. Medical notes are expected where sickness extends more than 2\nworkdays. These notes should be sent to the HR team (hr_team@clearpeaks.com) except in the\ncase of employees working from Spain, whose medical center will directly notify ClearPeaks’ HR\nteam.',
#  '### Employee Requiring Medical Attention  \nEmployees should report all work-related injuries and accidents immediately to their direct\nmanager and the HR Team.',
#  '### Visitors in the Workplace  \nFor safety, insurance, and other business considerations, only authorized visitors are allowed in\nthe workplace.  \nWhen a visitor or customer is planning to visit ClearPeaks office/s, a prior notification should be\nmade where possible to advice of the imminent visit, highlighting housekeeping requirements.',
#  '## 4. Standards of Conduct  \n### General Guidelines  \nAll employees are urged to become familiar with ClearPeaks rules and standards of conduct and\nare expected to follow these rules and standards faithfully in doing their own jobs and conducting\nthe company’s business.  \nAny abuse or misconduct will be taken into account in the Annual Performance Assessment. In\nthe case of severe misconduct, the result could imply immediate termination.',
#  '### Attendance and Punctuality  \nEmployees should start work according to the hours in the table below and to reasonably\ncomplete their projects by the end of assigned work hours.  \n#### Region Entry time End time\nSpain: 8:00 – 9:00 AM 5:00 – 6:00 PM\nCroatia: 9:00 AM 5:00 PM\nUAE: 9:00 AM 6:00 PM',
#  '### Work Schedule  \nUnless otherwise specified, employees are expected to work regular full-time per work week.  \n#### Region Work schedule (Hours)\nSpain: 40\nCroatia: 40\nUAE: 40',
#  '### Meal and Break Periods  \nEmployees have available a one-hour lunch break in Spain & UAE and 30 minutes in Croatia, which\nshould be ideally taken according to the table below. It is expected that employees schedule any\nbreak in coordination with customer schedules, where possible.  \n#### Region Meal period\nSpain: 13:00 – 15:00 PM\nCroatia: 13:00 – 15:00 PM\nUAE: 12:00 – 14:00 PM  \nThe morning breakfast break should be no longer than 30 minutes.',
#  '### Hybrid Working Model  \nClearPeaks is taking on a hybrid working model policy. Daily attendance to office is voluntary,\nhowever it is recommended that everyone works from the office once a week to preserve the\nrelationship with your team and other colleagues, to take a chance to review specific topics, and\nto maintain ClearPeaks team culture.  \nAlong these lines, we encourage you to be present in person at the following times defined by\nthe company:  \n- Group Manager Delivery Meetings (monthly)\n- Team Manager Delivery Meetings (twice a month)\n- On-site trainings\n- Corporate events\n- Project needs\n- When requested by the Manager  \nBesides the office location, Work from Home (WFH) may be conducted from the address informed\nto HR. An employee may also add a second WFH address in the same country of residence, which\nshould also be informed to HR. This second address is understood as an additional stable place\nfrom which you can work; and does not include sporadic and seasonal or similar places. Working\nfrom your second address should not affect the attendance to office explained above, and needs\nto be approved with your Team Manager and PM.  \nBear in mind that if at any time these addresses may change, HR must be informed accordingly.  \n#### Remote Work  \nEmployees hired in locations more than 120km away from any ClearPeaks office are considered\nfully remote.  \nThe above recommendations for office attendance will not apply to this model of work. However,\nsuch employees may be requested to visit any of the ClearPeaks offices for business matters. In\nthose cases, the company will sponsor transportation (from the initial location to the office and\nany transport required within the office’s city), meal allowances, and hotel if necessary. Corporate\nTravel Policy guidelines apply in these cases. This must be previously approved by the Manager,\nHR & Finance via email sent from the employee to all parties.  \nEmployees working in a remote model may also be sponsored for transportation, 1 hotel night, 1\nbreakfast and 1 lunch on the occasion of a corporate company event.  \n#### Working from a Different Location  \nEmployees with an A2 level or above, who have demonstrated excellent performance to date and\nhave been with the company for a minimum of one year, are allowed to utilise a maximum of 30\ncalendar days per year from a different location within the country of residence. During those\ndates the employee will be expected to attend all meetings, although they are not required to\nattend on-site.  \nThe employee must ensure a good internet connection, an adequate working space that\nguarantees concentration, and working on the same schedule as usual. This request must be\npreviously approved by the Account Manager, PM, HR & Ops via email sent from the employee to\nall parties.  \nThis policy does not apply to employees working in a project / client that requires office\nattendance.  \n#### Bank Holidays (Applicable only to Employees Working in Spain)  \nEmployees working in Spain are entitled to make the following exchanges for bank holidays as\ndefined in the working calendar for the Barcelona office:\n- 2 exchangeable regional bank holidays\n- 2 exchangeable local bank holidays  \nThis must be approved by the Manager, HR & Ops via email sent from the employee to all parties.',
#  '## Absence and Lateness  \nIn the event you are running late or absent from work, you are requested to contact your direct\nmanager and / or HR immediately to inform them of your lateness or absence highlighting any\npossible customer impact that this may cause.',
#  '## Unscheduled Absence  \nAbsence from work in excess of that indicated in the table below without notifying your supervisor\nor ClearPeaks member will be considered a voluntary resignation.  \nNumber of days\nSpain 3\nCroatia 3\nUAE 3',
#  '## Voice mail, out-of-office message, e-mail signatures, communication, etc.  \nClearPeaks has a standard voice mail message to record on the telephone when incoming calls\nreach the phone voice mail. Please contact your supervisor for details.  \nEmployees out-of-office for any reason should activate an automatic out-of-office reply in their\nemail, detailing the duration of the absence, when known, as well as contact details of a backup\nperson designated for his tasks.  \nClearPeaks has a standard e-mail signature to be included in any outbound e-mail. Please contact\nHR for details.  \nIn general employees should communicate in advance any planned absence to the managers,\ncustomers as well as their co-workers.',
#  "## Harassment Policy  \nClearPeaks does not / will not tolerate workplace harassment. With this protocol, ClearPeaks\nexpresses its zero tolerance for the occurrence in the entire organization of behaviors that\nconstitute harassment, and wants to underline its commitment to the prevention and create an\naction plan against harassment, in any of its manifestations, by informing all employees.  \nThis procedure is applicable to all people who carry out a work activity at ClearPeaks, and it\noffers protection against harassing behaviors produced during or as a result of the development\nof any work activity.  \n4.9.1 Definitions  \nHarassment situations can be classified into four blocks:  \nSexual harassment:  \nAny behavior carried out based on a person's sex, with the purpose or effect of violating their\ndignity and creating an intimidating, degrading or offensive environment.  \nGender based harassment:  \nUnwanted behavior (continuous and systematic) related to the gender of a person, with the\npurpose of violating the dignity of the person and creating an intimidating, hostile, degrading,\nhumiliating or offensive environment.  \nPsychological harassment or moral harassment at work (mobbing):  \nA situation in which a person or group of people engage in a set of behaviors characterized by\nextreme, abusive, and unfair psychological violence, systematically and recurrently, over a long\nperiod of time, on another person in the workplace.  \nCertain hostile actions can occur at work in a timely manner, but for the actions to become\nharassment they must be systematic, with a specific duration in time, directed always to the\nsame person.  \nSituations of pressure or labor conflict should not be confused with psychological harassment. In\nthe first case, it is about situations of disagreement as clashes, discussions and eventual conflicts\nthat can occur at work.  \nDiscriminatory acts (against e.g. race, ethnicity, religion, or convictions):  \nAny harassing behavior or conduct based on race, ethnicity, religion, conviction or personal or\nsocial circumstance, with the purpose of making it difficult for the harassed person to integrate\nand causing them harm.  \n4.9.2 Reporting procedure",
#  '### The process of handling a complaint for harassment is structured in four stages:  \n4.9.2.1 Reporting procedure  \nReporting of possible harassing conduct may be made by:  \n- The person in the organization who has been affected by the conduct or\n- Any person in the organization who has knowledge of the aforementioned facts.  \nThe communication must be made as soon as possible and will be done by completing the\nHarassment Complaint Form. The form will be sent by email to mireia.rodriguez@clearpeaks.com\n(HR Manager). If the communication directly affects this person, the email will be addressed to\nlaia.bofarull@clearpeaks.com (Talent Acquisition & Employer Branding Lead).  \n4.9.2.2 Initial assessment  \nIf the employee considers that after this meeting his/her situation can be resolved, they may\nchoose to end the procedure.  \nOtherwise, the person receiving the complaint will proceed to propose the adoption of\nprecautionary measures, when there are sufficient indications of the existence of harassment\n(physical separation of the complainant/s and the denounced person/s, granting of paid leave,\netc.).  \n4.9.2.3 Research  \nThe person responsible for the investigation will carry out the following actions:  \nInitial analysis of the complaint filed.\nInterview with the person presenting the complaint, to gather more information about the facts\ndenounced.\nInterview with the person denounced.\nInterviews with possible testimonies who voluntarily agree to be part of the investigation.  \n4.9.2.4 Resolution  \nIf there is not sufficiently proven evidence of the existence of a situation of harassment, the case\nwill be archived.\nIf there is sufficiently proven evidence of the existence of a situation of harassment, the\nManagement, with the support of HR, will decide the sanction to apply, considering that sexual or\ngender-based harassment is stipulated as a very serious offense.  \n4.9.3 Corrective measures  \nIf the investigation makes it possible to identify which control failures have allowed the\ndenounced conduct to take place, the corresponding corrective measures will be established, the\nimplementation of which will be coordinated by HR.  \nWhen the proposal requires the preparation of a new document or the modification of any of the\nexisting documents of the management system, HR will carry out a follow-up to guarantee that\nsaid action is carried out.',
#  '### Violent Behaviour in the Workplace  \nClearPeaks has adopted a policy prohibiting workplace violence. Consistent with this policy, acts\nor threats of physical violence, including intimidation, harassment, and/or coercion, which involve\nor affect ClearPeaks or which occur on ClearPeaks or client property, will not be tolerated. The\nuse of offensive language in a confrontational or abusive way will be considered as violent\nbehaviour.',
#  '### Confidential Information and Non-disclosure  \nThrough employment with ClearPeaks, employees agree that they will not disclose or use or refer\nto any of ClearPeaks confidential information, documentation or intellectual property, either\nduring or after their employment. ClearPeaks sincerely hopes that its relationship with its\nemployees will be long-term and mutually rewarding. However, employment with ClearPeaks\ninfers an obligation to maintain confidentiality, even after an employee resigns from ClearPeaks.  \nAll ClearPeaks customer or partner details and contact details within a customer or partner site\nare considered confidential to ClearPeaks and should not be discussed or referred to externally\nunless with written permission from ClearPeaks management.  \nAll business projects, leads, opportunities being managed by ClearPeaks, engaged in by ClearPeaks\nor being qualified by ClearPeaks should not be discussed or referred to externally unless with\nwritten permission from ClearPeaks management.  \nAny new employee will be asked to sign a Confidentiality & Non-disclosure Agreement included\nin the contract.  \nIn addition for those employees who are working from Spain, according to Spanish regulations,\nthe company has drawn up a manual of functions and obligations of personnel in matters of data\nprotection, which is made available to all employees and is located in the following LINK.',
#  '### Ethical Standards.  \nClearPeaks insists on the highest ethical standards in conducting its business. Doing the right thing\nand acting with integrity are the two driving forces behind ClearPeaks successes to date. When\nfaced with ethical issues, employees are expected to make the right professional decision\nconsistent with ClearPeaks principles and standards.',
#  '### Personal Image  \nEmployees of ClearPeaks are expected to present a clean and professional appearance while\nconducting business, in or outside of the office.  \nEmployee hygiene is an obvious but important aspect of our daily routine. The employee is\nexpected to present themselves with a clean, tidy and orderly appearance. Your supervisor should\ndetail explain to you what the basic levels of personal hygiene are if you are in doubt.',
#  '### Dress Code  \nWhen engaged on site at a customer, the dress code should be checked first with the customer\ncontact to establish whether the code is formal, business casual etc.  \nIt is a standard practice well accepted across Europe, to wear suits in dark colours, dark grey or\ndark blue with light blue or white shirt.  \nThe dress code should at minimum be the level of the customer, if not more formal where\nappropriate.  \nDressing in a fashion that is clearly unprofessional, that is deemed unsafe, or that negatively\naffects ClearPeaks reputation or image is not acceptable.  \nWhen working at the ClearPeaks office employees may wear casual clothes but always\nmaintaining a professional image in the event customers come to our office.',
#  '### Use of Equipment.  \nClearPeaks will provide employees with the equipment needed to do their job. This equipment\nremains the property of ClearPeaks.  \nClearPeaks property, including computers, phones, electronic mail, and voice mail, should be used\nonly for conducting company business. Incidental and occasional personal use of company\ncomputers, phones, or electronic mail and voice mail systems is permitted, but information and\nmessages stored in these systems will be treated no differently from other business-related\ninformation and messages.  \nAll computer equipment should be protected with adequate anti-virus software and be protected\nvia an active firewall.  \nNew employees are required to sign an Asset List when receiving their equipment. The list will\ndetail all the equipment provided by ClearPeaks – this equipment should be returned when\nfinalizing their contractual relationship with ClearPeaks.',
#  '### Use of the Internet  \nEmployees are responsible for using the Internet in a manner that is ethical and lawful. Use of the\nInternet must solely be for business purposes and must not interfere with employee productivity.  \nAny criminal activity performed over the internet will result in immediate termination. This\nincludes accessing pornographic sites, terrorist or religiously extremist related sites, drug\ntrafficking sites and P2P.  \nAny intended introduction of harmful computer viruses into the ClearPeaks network will result in\ninstant dismissal and police notification.',
#  '### Use of Computer Software  \nClearPeaks does not condone the illegal duplication of software. The copyright law is clear. The\ncopyright holder is given certain exclusive rights, including the right to make and distribute copies.\nThe only exception is the user’s right to make a backup copy for archival purposes.',
#  '### Smoking Policy  \nNo smoking of any kind is permitted inside any ClearPeaks office. Smoking may take place only in\ndesignated smoking areas outside ClearPeaks facilities.',
#  '### Alcohol and Substance Abuse  \nIt is ClearPeaks policy that the workplace be free of illicit drugs and alcoholic beverages, and free\nof their use. In addition to damage to respiratory and immune systems, malnutrition, seizures,\nloss of brain function, liver damage, and kidney damage, the abuse of drugs and alcohol has been\nproven to impair the coordination, reaction time, emotional stability, and judgment of the user.\nThis could have tragic consequences where demanding or stressful work situations call for quick\nand sound decisions to be made.',
#  '### Bribery Policy  \nIt is central to the values of ClearPeaks that all its activities are conducted honestly and in\naccordance with the law and good business practice. Any corrupt business activity is therefore\ncontrary to ClearPeaks values and will not be tolerated.  \nFailure to comply with this policy will be regarded as a serious disciplinary offence capable of\nleading to summary dismissal.  \nClearPeaks will not support or compensate any person convicted of an offence under the Bribery\nAct.  \nSpecific rules:  \n1. Whenever an employee deals with a supplier, customer or government agency on\nbehalf of ClearPeaks, he or she has an obligation to act solely in the best interest of\nClearPeaks. This obligation includes not only those acts formalized by written contracts\nbut also covers everyday business relationships with suppliers, customers, government\nofficials and government employees. Every ClearPeaks Person shall treat with the\nutmost caution any offer of gift, payment, favour or hospitality that is made to him or\nher personally and should recognize that he or she will be held personally responsible\nfor all decisions connected with the acceptance or offer of gifts or hospitality and for\navoiding the risk of damage to public confidence in ClearPeaks.\n2. No employee shall ask for, solicit or accept (directly or indirectly) a financial or other\nadvantage from any person with the intent that a public or business function should be\nimproperly performed.\n3. No employee shall offer or give (directly or indirectly) a financial or other advantage to\nany person with the intent that a public or business function should be improperly\nperformed.\n4. The rules in paragraphs 2 and 3 apply\n- worldwide – that is to say, wherever the bribe is offered, requested or given;\n- whether or not the person requesting or receiving the bribe is responsible for\nperforming the relevant business or public function – indirect bribes are forbidden;\n- whether or not the bribe is actually paid or received; and\n- whether or not the performance of the relevant business or public function is\nactually affected.\n5. A financial advantage is to be interpreted widely. It need not involve the payment of\nmoney or giving of gifts. Extravagant, unusual or unexplained hospitality will be\nincluded. Acceptance or giving of gifts or hospitality must be limited to incidental items\nor activities which are:\n- demonstrably and wholly of an advertising or promotional nature;\n- of insignificant intrinsic value;\n- generally recognized as not likely to cause any reasonable person to believe that\nthe recipient or any other person might be influenced by such gift or hospitality\nand;\n- of such a nature that ClearPeaks is unlikely to be embarrassed or obligated.  \n6. Cash payments are never acceptable.\n7. Payments, gifts or hospitality which are properly regarded as a financial advantage\nmust be promptly returned. If return of a gift is not practicable because of its nature, it\nmay be given to a charitable institution and the supplier informed of its disposition.\nThis must be reported in writing to the ClearPeaks HR Team.',
#  '### Solicitations and Distributions  \nSolicitation for any cause during working time and in working areas is not permitted. Employees\nare not permitted to distribute non-company literature in work areas at any time during working\ntime.',
#  '### Complaint Procedure  \nEmployees who observe, learn of, or, in good faith, suspect a violation of the standards of conduct\nof ClearPeaks should immediately report to ClearPeaks management.',
#  '### Corrective Procedure  \nUnacceptable behaviour may be dealt with in any of the following manners: (a) Oral warning, (b)\nWritten Warning and (c) Termination.',
#  '### Crisis Suspension  \nAn employee who commits any serious violation of ClearPeaks policies at minimum will be\nsuspended without pay pending an investigation of the situation. Following the investigation, the\nemployee may be terminated without any previous disciplinary action having been taken.',
#  '### Transfer Policy  \nClearPeaks recognizes that a desire for career growth and other needs may lead an employee to\nrequest a transfer to another position. An employee with proper qualifications will be eligible for\nconsideration for the transfer.  \n#### Outside Employment & Non-solicitation  \nEmployees may not take up employment or seek employment, either for pay or as a donation of\ntheir personal time, with a customer or partner of ClearPeaks unless they have completed 1\ncomplete calendar year free from ClearPeaks contractual employment. Each employee is asked to\nsign a Non-Solicitation Agreement, formally agreeing to this.  \nEmployees may not take up freelance or subcontract work with a customer or partner of\nClearPeaks unless they have completed 1 complete calendar year free from ClearPeaks\ncontractual employment.  \nEmployees may not do work on their own, outside of work hours or over weekends, if it competes\nor interferes in any way with the sales of ClearPeaks products or services or indeed if it impacts\ntheir own personal performance at ClearPeaks.  \n#### Employment Termination or Resignation  \nAfter the application of disciplinary steps, if it is determined by management that an employee’s\nperformance has not met the basic and agreed requirements, or if the employee is again in\nviolation of ClearPeaks practices, rules, or standards of conduct, employment with ClearPeaks will\nbe terminated.  \nEmployee voluntary resignation must be communicated to ClearPeaks with the minimum number\nof days shown in the table below:  \nLegal requirements - ClearPeaks expectations  \nSpain: 15 days - 1 month\nCroatia 1 month - 1 month\nUAE 1 month - 1 month  \n#### Exit Interview  \nIn a voluntary termination case, ClearPeaks management would like to conduct an exit interview\nto discuss the employee’s reasons for leaving and any other impressions that the employee may\nhave about ClearPeaks.',
#  '## 5. Compensation Policies  \n### Compensation & Benefits  \nRefer to the **ClearPeaks Compensation & Benefits** document.',
#  '### Timekeeping Procedures  \nClearPeaks is obliged to keep accurate records of the time worked by employees. Each employee\nmust fill out the appropriate timesheet weekly, and timesheet must be completed in accordance\nwith the time-reporting guidelines – see Kimble User Manual.pdf  \nTimesheet record App - Period\nSpain Kimble - Weekly, Payfit - Monthly\nCroatia: Kimble - Weekly\nUAE: Kimble Weekly  \nTimesheets should be made available to the company administrator at the end of each week for\nKimble and for Payfit at the end of each month. This is vital to the success of our company. Any\ndelay in the submission of the Timesheet may cause a delay in the invoicing process.  \nThe employee will be provided a login and password to the ClearPeaks time tracking tool allowing\nfor online time logging.',
#  '### Payroll and Pay Days  \nRegular full-time salary employees are paid monthly normally at the end of each calendar month\nor at the start of the upcoming month.  \nPeriod\nSpain: Last week of current month\nCroatia: First week of upcoming month\nUAE: Last week of current month',
#  '### Performance and Salary Reviews  \nWe want to help employees to succeed in their careers and to grow. In an effort to support this\ngrowth and success, we have implemented an Annual Performance Plan (APP). Feedback includes\na performance and core competence evaluation, goal statement for coming year and a review of\naccomplishments. Customer input, where appropriate, has a role in influencing the resulting\nperformance evaluation.  \nSalary reviews typically occur in conjunction with the annual performance review process. The\ncalculation and implementation of changes in base salary depend on both company and personal\nperformance and will typically occur at the beginning of the New Year.',
#  '### Opportunities for Advancement – Progression and Promotion  \nWe offer employees with every opportunity for advancing to other positions or opportunities\nwithin the company. Approval of progression moves, or promotions depends largely upon\ntraining, experience, work record, and business need. However, we reserve the right to look\noutside the company for potential employees as well.',
#  '### Training and Professional Development  \n### Training and Professional Development  \nWe would like to provide employees with every opportunity for advancing to other positions or\nopportunities within the company. Approval of progression moves, or promotions depends largely\nupon training, experience, work record, and business need. However, ClearPeaks reserves the\nright to look outside the company for potential employees as well.  \n### Training and Professional Development  \nWe believe that education leads to self-improvement and recognizes that the skills and knowledge\nof its employees are critical to the success of the organization. In that vein, we provide training\nthat is necessary for an employee’s current job or that which will help an employee prepare for\nmore responsibilities or promotions within the organization.',
#  '### Holiday Policy  \nAll regular status ClearPeaks employees are eligible to accrue vacation time. The vacation accrual\npolicy for regular full-time employees and regular part-time employees is as follows:  \nVacation days per year Public holidays days per year\nSpain: 23 + 2* 14\nCroatia: 23 + 2* 14\nUAE: 25 13  \n*December 24th and 31st_^ _as Holiday as per the Spanish Labour Agreement.  \nThese days should be enjoyed within the corresponding calendar year.  \nPublic holidays will be considered in addition to the employee statutory vacation days.  \nFor Public holidays in Spain and Croatia, the calendar will be published and shared with the\nemployees by the end of the previous year. In the case of ME, a tentative calendar will be\npublished at the beginning of the year. Dates are subject to the moon, so a confirmation will be\nsent as soon as the government corroborates the dates. Employees will be updated accordingly\nby the HR department.  \n#### Tactical period vacation planning  \nBased on customer demand, it is recommended that employees take the major part of their\nvacations during the periods shown below:  \nSummer period: Winter period\nSpain June – July - August : Christmas – New Year period\nCroatia June – July - August : Christmas – New Year period\nUAE Ramadan – Eid period : Christmas – New Year period  \nIdeally, vacation blocks should be taken in 2-week blocks, although a maximum of 3 weeks in 1\nvacation block will be approved. Any request exceeding a 3-week absence will require ClearPeaks\nmanagement approval, based on exceptional circumstances, and should be requested at least 3\nmonths in advance of the vacation date.  \n#### Vacation request\nVacation time should be requested following the process below:  \nPlease note that any request to work on a non-business day needs to be approved in advance by\nthe Project Manager, Account Manager and the Operations Manager, otherwise it will not be\ncompensated.  \nFor non-consulting employees i.e. Sales, Finance & Operations, HR and Marketing, there should\nalways be senior cover in office, so careful coordination and planning is required to ensure we\nhave no management gaps especially in peak vacation periods. Overlapping vacation of senior\nmembers will risk being rejected.  \n#### Carry over vacation days\nIf an employee does not consume their accrued vacation days before the end of the year, the\nemployee is conditionally eligible to carry over a maximum of 5 vacation days into the following\nyear, independently of their location.  \nAny carry over vacation days beyond the 5 vacation days will be simply lost, so careful planning\nand consideration should be made by all employees early in the year to ensure all vacation can be\nenjoyed without push back or worst case, losing vacation days.  \nAt minimum, all carried over days must be consumed by the end of Q1 of the following year, that\nis, before March 31st. Any carried-over vacation days not consumed by the end of March 31st of\nthe following year will be lost.  \nThe conditions which will be accepted to honour carry-over vacation are:  \n1. If a consultant has had difficulty to consume their entire vacation allowance due to\ncustomer project demands on billable projects. Non-billable project demands will not be\nconsidered.\n2. Exceptional, non-customer/project related carry-over vacation days will be honoured\nonly if they have been approved by both your Team Manager and Operations manager\nno later than September 1st of the active year. Exceptional carry-over days considered\nwill be for example, to extend a honeymoon or to enjoy a well-in-advance planned long\ntrip.\n3. Customer/project driven carry-over vacation days will only be “cashable” if the laws of\nthe country permit this practice, and if they are agreed with your Team Manager and HR\nmanager immediately at the time the employee came to know of the carry-over risk. A\nmaximum of 5 vacation days will be compensated, but again, subject to le ...
#  '### Non-business working daytime policy  \nWhenever requested by a client to work on a non-business day, the procedure to get the approval\nis as follows:  \n**Time and Material Project**  \n1. Project Manager to request non-business day to the Sales Account Manager and\nOperations. Explain the situation and the project impact.\n2. Ensure the conditions that will apply to the non-business day are clear for the customer,\nOperations and Finance.\n3. Operations to send approval to the Project Manager cc’ing the Sales Account Manager\nand Finance.\n4. Project Manager to inform of the non-business day to the project team impacted cc’ing\nHR and Finance & Operations.\n5. HR to compensate the days.  \n**Fixed Price Projects**  \n1. Project Manager to request non-business day to the Sales Account Manager and\nOperations. Explain the situation and the project impact. Check if a change request is\nneeded.\n2. If a change request is needed, Sales Account Manager to send the change request to the\ncustomer cc’ing the Project Manager, HR and Finance & Operations.\n3. Once the change request is approved, Sales Account Manager to send the approval to\nthem Project Manager, HR and Finance & Operations.\n4. Project Manager to inform of the non-business day to the project team impacted cc’ing\nHR and Finance & Operations.\n5. HR to compensate the days.  \n#### Special days off  \n##### Bereavement Leave  \nIn reference to the country labour law: for first level relatives (i.e.: parents, siblings, children),\ndays off are permitted and it can be extended depending on the travel distance from the office.  \nDays off\nSpain 2 – 4\nCroatia Up to 7 days per year*\nUAE 3/5 days*  \nDuring a calendar year, an employee has the right to exemption from the obligation to work with\ncompensation of salary (paid leave) for important personal needs, especially in connection with\nmarriage, birth of a child, serious illness, or death of a close family member. (Only apply in Croatia).\n*For Abu Dhabi employee, in case of 1st degree family member’s death (Wife, Husband, child) the\nemployee has 5 days bereavement leave. However, if in case of 2nd degree family member’s death\n(Parents, Siblings, Grandparents only) the employee will have 3 days bereavement leave._  \n##### Jury Duty  \nClearPeaks is committed to supporting the communities in which ClearPeaks operates, including\nsupporting ClearPeaks employees in fulfilling their responsibilities to serve as jurors whenever it\nis possible. When an employee receives notification regarding upcoming jury duty, it is their\nresponsibility to notify their direct supervisor and Human Resources within one business day of\nreceiving the notice.  \n##### Family emergency  \nIn special circumstances, ClearPeaks may grant a leave for a personal reason after an internal\napproval and in reference to the country labour law:  \nDays off\nSpain 2\nCroatia Up to 7 days per year*\nUAE 0  \n*During a calendar year, an employee has the right to exemption from the obligation to work with\ncompensation of salary (paid leave) for important personal needs, especially in connection with\nmarriage, birth of a child, serious illness, or death of a close family member. (Only apply in Croatia)._  \n##### Maternity leave\nIn agreement with the country labour law, days permitted are the following and numbers may\nchange, ClearPeaks will always follow the labour law and the employee must communicate to the\ncompany the date of birth.  \nDays off\nSpain 112\nCroatia 70 *\nUAE 90\n*usually starts 28 days before the expected day of birth and lasts till the baby is 6 months old\n(there are 2 parts: mandatory 70 days from birth and additional).  \n##### Paternity leave  \nIn agreement with the country labour law, days permitted are the following and numbers may\nchange, ClearPeaks will always follow the labour law and the employee must communicate to the\ncompany the date of birth.  \nDays off\nSpain 112\nCroatia 70 *\nUAE 5\n* If the mother u ...
#  '## 6. Travel Expenses  \nRefer to the **ClearPeaks Expense & Purchasing Policy** document.',
#  '## 7. Company Supplies & Purchases  \nRefer to the **ClearPeaks Expense & Purchasing Policy** document.',
#  '## 8. Employee Communications',
#  '## Open communications  \nWe encourage employees to discuss any issues they may have with a co-worker directly with that\nperson. If a resolution is not reached, employees should arrange a meeting with their direct\nsupervisor. If the concern, problem, or issue is not properly addressed, employees should contact\nthe company administrator.  \nClearPeaks depends on open, honest and candid feedback and communication from each and\nevery employee. Employees withholding information which can be considered beneficial to their\nco-workers will be frowned upon.',
#  '## Staff Meetings  \nIn order to keep the communication channels open, ClearPeaks schedules regular team and\ncompany meetings.',
#  '## Suggestions  \nClearPeaks encourages all employees to bring forward their suggestions and good ideas about\nmaking ClearPeaks a better place to work and enhancing service to ClearPeaks customers. Any\nemployee who sees an opportunity for improvement is encouraged to talk it over with\nmanagement. Management can help bring ideas to the attention of the people in the organization\nthat will be responsible for possibly implementing them. All suggestions are valued.',
#  '## Closing Statement  \nSuccessful working conditions and relationships depend upon successful communication. It is\nimportant that employees stay aware of changes in procedures, policies, and general information.\nIt is also important to communicate ideas, suggestions, personal goals, or problems as they affect\nwork at ClearPeaks.  \n```\nProprietary and Confidential © 202 2 ClearPeaks. All rights reserved.\nAll information contained in this document is confidential and proprietary to ClearPeaks.\nNo part of this document may be photocopied, electronically transferred, modified, or reproduced in any manner without the prior written content of ClearPeaks.\n```']
